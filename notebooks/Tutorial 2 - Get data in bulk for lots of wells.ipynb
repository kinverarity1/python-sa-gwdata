# %% [markdown]
# # Tutorial 2 - Get data in bulk for lots of wells

# %%
import sa_gwdata

# %%
wells = sa_gwdata.find_wells_in_lat_lon([-34.65, -34.62], [135.47, 135.51])

# %%
wells
# Out:
# ['5928-10', '5928-33', '5928-39', '5928-62', '5928-64', '5928-69', '5928-72', '5928-74', '5928-83', '5928-86', '5928-118', '5928-176', '5928-177', '5928-178', '5928-199', '5928-201', 'LKW042', '5928-216', '5928-234', '5928-237', '5928-240', '5928-241', '5928-243', '5928-244', '5928-248', '5928-250', '5928-251', '5928-252', '5928-253', '5928-254', '5928-255', '5928-256', '5928-257', '5928-261', 'LKW041', '5928-263', '5928-264', '5928-265', '5928-267', '5928-271', '5928-275', '5928-281', '5928-287', 'LKW037', '5928-302', 'LKW038', 'LKW039', 'LKW061', 'LKW040', '5928-307', 'LKW043', '5928-346', '5928-385', '5928-392', '5928-431', 'LKW058', 'LKW060', '5928-437', '5928-438', '5928-439', '5928-445', '5928-447', 'LKW063', 'LKW064', '5928-463', 'LKW027', 'LKW025', 'LKW026', '6028-2321']

# %% [markdown]
# ## Well summary data

# %%
summ = sa_gwdata.wells_summary(wells)
summ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 59 columns):
# dh_no                  69 non-null int64
# unit_hyphen            69 non-null object
# unit_long              69 non-null int64
# dh_name                27 non-null object
# network                19 non-null object
# obs_no                 15 non-null object
# drillhole_class        69 non-null object
# aquifer                26 non-null object
# orig_drilled_depth     53 non-null float64
# orig_drilled_date      54 non-null datetime64[ns]
# max_drilled_depth      54 non-null float64
# max_drilled_date       57 non-null datetime64[ns]
# latest_open_depth      54 non-null float64
# latest_open_date       57 non-null datetime64[ns]
# latest_permit_no       37 non-null float64
# cased_to               43 non-null float64
# casing_min_diam        53 non-null float64
# purpose                52 non-null object
# latest_status          43 non-null object
# ...

# %%
summ.head().T
# Out:
#                                        0                    1  \
# dh_no                               7014                 7037
# unit_hyphen                      5928-10              5928-33
# unit_long                      592800010            592800033
# dh_name                           SPRING                  NaN
# network                              NaN                  NaN
# obs_no                               NaN                  NaN
# drillhole_class                       WP                   WW
# aquifer                              NaN                  NaN
# orig_drilled_depth                   NaN                   13
# orig_drilled_date                    NaT  1969-01-01 00:00:00
# max_drilled_depth                    NaN                   13
# max_drilled_date                     NaT  1969-01-01 00:00:00
# latest_open_depth                    NaN                   13
# latest_open_date                     NaT  1969-01-01 00:00:00
# ...

# %% [markdown]
# ## Water level measurements (manual observations)

# %%
wls = sa_gwdata.water_levels(wells)

# %%
wls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2782 entries, 0 to 2781
# Data columns (total 21 columns):
# dh_no              2782 non-null int64
# network            2619 non-null object
# unit_long          2782 non-null int64
# aquifer            2595 non-null object
# easting            2782 non-null float64
# northing           2782 non-null float64
# zone               2782 non-null int64
# unit_hyphen        2782 non-null object
# obs_no             2611 non-null object
# obs_date           2781 non-null datetime64[ns]
# dtw                2677 non-null float64
# swl                2674 non-null float64
# rswl               2674 non-null float64
# pressure           0 non-null float64
# temperature        21 non-null float64
# dry_ind            54 non-null object
# anomalous_ind      2782 non-null object
# pump_ind           2782 non-null object
# measured_during    2782 non-null object
# data_source        2782 non-null object
# comments           115 non-null object
# ...

# %%
wls.head()
# Out:
#    dh_no network  unit_long aquifer    easting    northing  zone unit_hyphen  \
# 0   7043     NaN  592800039     NaN  543101.33  6168619.29    53     5928-39
# 1   7066     NaN  592800062     NaN  543145.34  6168680.30    53     5928-62
# 2   7068     NaN  592800064     NaN  543130.33  6168528.33    53     5928-64
# 3   7073     NaN  592800069     NaN  543107.40  6168682.36    53     5928-69
# 4   7076     NaN  592800072     NaN  543331.32  6168578.29    53     5928-72
#
#   obs_no   obs_date  ...    swl  rswl  pressure  temperature  dry_ind  \
# 0    NaN 1976-01-05  ...   8.50  5.08       NaN          NaN      NaN
# 1    NaN 1975-10-28  ...  10.59  3.69       NaN          NaN      NaN
# 2    NaN 1975-10-28  ...   7.35  2.61       NaN          NaN      NaN
# 3    NaN 1975-10-27  ...  11.48  4.33       NaN          NaN      NaN
# 4    NaN 1975-10-27  ...   7.55  4.38       NaN          NaN      NaN
#
#   anomalous_ind pump_ind measured_during data_source comments
# ...

# %% [markdown]
# ## Salinity samples

# %%
tds = sa_gwdata.salinities(wells)

# %%
tds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1644 entries, 0 to 1643
# Data columns (total 20 columns):
# dh_no              1644 non-null int64
# network            1473 non-null object
# aquifer            1603 non-null object
# unit_hyphen        1644 non-null object
# unit_long          1644 non-null int64
# obs_no             890 non-null object
# collected_date     1644 non-null datetime64[ns]
# collected_time     58 non-null object
# tds                1644 non-null int64
# ec                 1644 non-null int64
# ph                 247 non-null float64
# Sample_type        1644 non-null object
# anomalous_ind      1644 non-null object
# Test_Place         1059 non-null object
# extract_method     1474 non-null object
# measured_during    1644 non-null object
# data_source        1644 non-null object
# easting            1644 non-null float64
# northing           1644 non-null float64
# zone               1644 non-null int64
# ...

# %%
tds.head()
# Out:
#    dh_no network aquifer unit_hyphen  unit_long obs_no collected_date  \
# 0   7014     NaN     NaN     5928-10  592800010    NaN     1957-03-14
# 1   7014     NaN     NaN     5928-10  592800010    NaN     1957-03-19
# 2   7043     NaN     NaN     5928-39  592800039    NaN     1976-01-05
# 3   7066     NaN     NaN     5928-62  592800062    NaN     1975-10-21
# 4   7068     NaN     NaN     5928-64  592800064    NaN     1975-08-03
#
#   collected_time    tds     ec   ph Sample_type anomalous_ind Test_Place  \
# 0            NaN  32673  50046  NaN           S             N        NaN
# 1            NaN  32603  50015  NaN           W             N          L
# 2            NaN   1210   2190  8.0           S             N        NaN
# 3            NaN   3552   6320  7.5           S             N        NaN
# 4            NaN   1049   1900  8.3           S             N        NaN
#
#   extract_method measured_during data_source    easting    northing  zone
# ...

# %% [markdown]
# ## Water chemistry analyses

# %%
chem = sa_gwdata.water_chem(wells)
chem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 778 entries, 0 to 777
# Data columns (total 9 columns):
# dh_no             778 non-null int64
# unit_hyphen       778 non-null object
# obs_no            216 non-null object
# sample_no         778 non-null int64
# collected_date    778 non-null datetime64[ns]
# analysis_code     778 non-null object
# analysis_name     778 non-null object
# value             778 non-null float64
# unit              778 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 54.8+ KB

# %%
chem.head()
# Out:
#    dh_no unit_hyphen obs_no  sample_no collected_date analysis_code  \
# 0   7014     5928-10    NaN     394822     1957-03-19            Ca
# 1   7014     5928-10    NaN     394822     1957-03-19            Cl
# 2   7014     5928-10    NaN     394822     1957-03-19          HARD
# 3   7014     5928-10    NaN     394822     1957-03-19             K
# 4   7014     5928-10    NaN     394822     1957-03-19            Mg
#
#              analysis_name      value  unit
# 0                  Calcium    400.425  mg/L
# 1                 Chloride  18054.750  mg/L
# 2  Total Hardness as CaCO3   6090.450  mg/L
# 3                Potassium  10224.375  mg/L
# 4                Magnesium   1236.900  mg/L

# %% [markdown]
# ## Elevation surveys

# %%
elev = sa_gwdata.elevation_surveys(wells)
elev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 12 columns):
# dh_no             70 non-null int64
# unit_hyphen       70 non-null object
# obs_no            16 non-null object
# network           20 non-null object
# elev_date         60 non-null datetime64[ns]
# ground_elev       66 non-null float64
# ref_elev          20 non-null float64
# survey_meth       67 non-null object
# vert_accuracy     50 non-null float64
# ref_point_type    20 non-null object
# applied_date      13 non-null datetime64[ns]
# comments          56 non-null object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(6)
# memory usage: 6.7+ KB

# %%
elev.head()
# Out:
#    dh_no unit_hyphen obs_no network  elev_date  ground_elev  ref_elev  \
# 0   7014     5928-10    NaN     NaN 2018-08-31        2.234       NaN
# 1   7037     5928-33    NaN     NaN 2018-08-31       13.148       NaN
# 2   7043     5928-39    NaN     NaN 2018-08-31       13.575       NaN
# 3   7066     5928-62    NaN     NaN 2018-08-31       14.283       NaN
# 4   7068     5928-64    NaN     NaN 2018-08-31        9.960       NaN
#
#   survey_meth  vert_accuracy ref_point_type applied_date  \
# 0         DEM            9.8            NaN          NaT
# 1         DEM            9.8            NaN          NaT
# 2         DEM            9.8            NaN          NaT
# 3         DEM            9.8            NaN          NaT
# 4         DEM            9.8            NaN          NaT
#
#                                             comments
# 0  Ground elevation has been interpolated from th...
# 1  Ground elevation has been interpolated from th...
# ...

# %% [markdown]
# ## Well construction events (summary information)

# %%
con = sa_gwdata.construction_events(wells)
con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 29 columns):
# dh_no                   81 non-null int64
# unit_hyphen             81 non-null object
# obs_no                  32 non-null object
# completion_date         77 non-null datetime64[ns]
# total_depth             56 non-null float64
# final_depth             56 non-null float64
# current_depth           72 non-null float64
# permit_no               38 non-null float64
# backfilled              81 non-null object
# casing_from             54 non-null float64
# casing_to               44 non-null float64
# casing_min_diam         54 non-null float64
# casing_material         34 non-null object
# pcemented               81 non-null object
# pcement_from            8 non-null float64
# pcement_to              8 non-null float64
# pzone_from              30 non-null float64
# pzone_to                30 non-null float64
# pzone_min_diam          25 non-null float64
# ...

# %%
con.tail().T
# Out:
#                                                                      76  \
# dh_no                                                            247806
# unit_hyphen                                                    5928-439
# obs_no                                                              NaN
# completion_date                                     2009-05-22 00:00:00
# total_depth                                                          29
# final_depth                                                          29
# current_depth                                                        29
# permit_no                                                        159162
# backfilled                                                            N
# casing_from                                                           0
# casing_to                                                            25
# casing_min_diam                                                     200
# ...

# %% [markdown]
# ## Construction details: water cuts, drilling, casing, and production zones

# %% [markdown]
# The is a bit different to all the other calls - it returns up to four separate DataFrames, inside a dictionary.

# %%
cond = sa_gwdata.construction_details(wells)
cond.keys()
# Out:
# dict_keys(['water_cuts', 'drilling', 'casing', 'prod_zones'])

# %%
cond["water_cuts"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 11 columns):
# dh_no             125 non-null int64
# unit_hyphen       125 non-null object
# water_cut_date    125 non-null datetime64[ns]
# depth_from        123 non-null float64
# depth_to          26 non-null float64
# swl               36 non-null float64
# yield             125 non-null float64
# test_method       24 non-null object
# tds               100 non-null float64
# ec                100 non-null float64
# sample_type       100 non-null object
# dtypes: datetime64[ns](1), float64(6), int64(1), object(3)
# memory usage: 10.9+ KB

# %%
cond["water_cuts"].tail()
# Out:
#       dh_no unit_hyphen water_cut_date  depth_from  depth_to    swl  yield  \
# 120   11282   6028-1043     1959-12-02       79.25       NaN    NaN    0.0
# 121   11282   6028-1043     1959-12-03       82.30       NaN    NaN    0.0
# 122   11300   6028-1061     1960-01-26       28.04       NaN  26.21    0.0
# 123   11301   6028-1062     1960-01-01       24.99       NaN  24.99    0.0
# 124  198986   6028-2321     2004-02-25       16.20      21.0  16.20    0.4
#
#     test_method     tds      ec sample_type
# 120         NaN  2301.0  4131.0           S
# 121         NaN  2301.0  4131.0           S
# 122         NaN     NaN     NaN         NaN
# 123         NaN     NaN     NaN         NaN
# 124        PUMP     NaN     NaN         NaN

# %%
cond["drilling"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
# dh_no           50 non-null int64
# unit_hyphen     50 non-null object
# depth_from      48 non-null float64
# depth_to        48 non-null float64
# hole_diam       46 non-null float64
# drill_method    50 non-null object
# comments        1 non-null object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 2.9+ KB

# %%
cond["drilling"].tail()
# Out:
#      dh_no unit_hyphen  depth_from  depth_to  hole_diam drill_method comments
# 45   11282   6028-1043         0.0     62.00        NaN          CAB      NaN
# 46   11282   6028-1043         0.0     82.30      152.0          CAB      NaN
# 47   11300   6028-1061         0.0     90.83      127.0          PER      NaN
# 48   11301   6028-1062         0.0     60.35      127.0          PER      NaN
# 49  198986   6028-2321         0.0     21.00      190.0          CAB      NaN

# %%
cond["casing"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
# dh_no              61 non-null int64
# unit_hyphen        61 non-null object
# depth_from         58 non-null float64
# depth_to           48 non-null float64
# casing_diam        61 non-null int64
# casing_material    37 non-null object
# cement_method      15 non-null object
# cement_from        14 non-null float64
# cement_to          14 non-null float64
# comments           11 non-null object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 4.9+ KB

# %%
cond["casing"].tail()
# Out:
#      dh_no unit_hyphen  depth_from  depth_to  casing_diam casing_material  \
# 56  283736    5928-459       -0.48     34.89          102             PVC
# 57   11282   6028-1043        0.00     42.92          152             STL
# 58   11282   6028-1043        0.00     43.00           80             PVC
# 59   11300   6028-1061        0.00     32.61           63             GLI
# 60  198986   6028-2321        0.00     13.20          125             PVC
#
#    cement_method  cement_from  cement_to     comments
# 56           NaN          NaN        NaN          NaN
# 57           NaN          NaN        NaN          NaN
# 58             N         49.0       62.0  Backfilled.
# 59           NaN          NaN        NaN          NaN
# 60             P          0.0        0.5          NaN

# %%
cond["prod_zones"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 9 columns):
# dh_no             44 non-null int64
# unit_hyphen       44 non-null object
# pzone_type        44 non-null object
# depth_from        33 non-null float64
# depth_to          33 non-null float64
# pzone_diam        28 non-null float64
# pzone_material    26 non-null object
# pzone_aperture    13 non-null float64
# comments          8 non-null object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 3.2+ KB

# %%
cond["prod_zones"].tail()
# Out:
#      dh_no unit_hyphen pzone_type  depth_from  depth_to  pzone_diam  \
# 39  283736    5928-459         SC       34.89     58.52       102.0
# 40   11282   6028-1043         SC       43.00     49.00        80.0
# 41   11282   6028-1043        UKN       42.92     82.30         NaN
# 42   11300   6028-1061        UKN       32.61     90.83         NaN
# 43  198986   6028-2321         SC       13.20     19.20       125.0
#
#    pzone_material  pzone_aperture                     comments
# 39            PVC             NaN                          NaN
# 40            PVC             NaN  terra firma and end capped.
# 41            NaN             NaN                          NaN
# 42            NaN             NaN                          NaN
# 43            PVC             1.0      Hard completion of base

# %% [markdown]
# ## Drillers logs

# %%
dlogs = sa_gwdata.drillers_logs(wells)
dlogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 9 columns):
# DHNO           147 non-null int64
# Unit_No        147 non-null object
# Obs_No         50 non-null object
# log_date       147 non-null object
# logger_name    144 non-null object
# depth_from     147 non-null float64
# depth_to       147 non-null float64
# lith_code      147 non-null object
# description    129 non-null object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 10.5+ KB

# %%
dlogs.head()
# Out:
#    DHNO  Unit_No Obs_No    log_date logger_name  depth_from  depth_to  \
# 0  7087  5928-83    NaN  03/11/1976    SEIDEL J        0.00      2.00
# 1  7087  5928-83    NaN  03/11/1976    SEIDEL J        2.00     16.00
# 2  7087  5928-83    NaN  03/11/1976    SEIDEL J       16.00     21.00
# 3  7090  5928-86    NaN  24/01/1977   WHITE D W        0.00      2.74
# 4  7090  5928-86    NaN  24/01/1977   WHITE D W        2.74      5.48
#
#   lith_code                  description
# 0      LMST               soft limestone
# 1      SDST        soft clayey sandstone
# 2      SDST  soft porus shelly sandstone
# 3      SDST                    sandstone
# 4      SDST                    sandstone

# %% [markdown]
# ## Stratigraphic logs

# %%
slogs = sa_gwdata.strat_logs(wells)
slogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
# dh_no          8 non-null int64
# unit_hyphen    8 non-null object
# depth_from     8 non-null float64
# depth_to       8 non-null float64
# strat_name     8 non-null object
# gis_code       8 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 512.0+ bytes

# %%
slogs.head()
# Out:
#     dh_no unit_hyphen  depth_from  depth_to             strat_name gis_code
# 0    7087     5928-83         0.0      21.0  Bridgewater Formation   I---cb
# 1    7220    5928-216         0.0       6.6  Bridgewater Formation   I---cb
# 2    7241    5928-237         0.0      14.8  Bridgewater Formation   I---cb
# 3  247524    5928-435         0.0      18.0  Bridgewater Formation   I---cb
# 4  247525    5928-436         0.0      22.0  Bridgewater Formation   I---cb

# %% [markdown]
# ## Hydrostratigraphic logs

# %%
hslogs = sa_gwdata.hydrostrat_logs(wells)
hslogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 14 columns):
# dh_no                          39 non-null int64
# unit_hyphen                    39 non-null object
# unit_depth_from                39 non-null float64
# unit_depth_to                  17 non-null float64
# subunit_depth_from             0 non-null float64
# subunit_depth_to               0 non-null float64
# hydro_type                     0 non-null float64
# hydro_depth_to_greater_flag    23 non-null object
# comments                       2 non-null object
# map_symbol                     39 non-null object
# strat_name                     39 non-null object
# subunit_comments               0 non-null float64
# subunit_code                   0 non-null float64
# subunit_desc                   0 non-null float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 4.4+ KB

# %%
hslogs.head()
# Out:
#    dh_no unit_hyphen  unit_depth_from  unit_depth_to  subunit_depth_from  \
# 0   7220    5928-216              0.0            NaN                 NaN
# 1   7238    5928-234              0.0            NaN                 NaN
# 2   7241    5928-237              0.0            NaN                 NaN
# 3   7254    5928-250              0.0            NaN                 NaN
# 4   7269    5928-265              0.0            NaN                 NaN
#
#    subunit_depth_to  hydro_type hydro_depth_to_greater_flag comments  \
# 0               NaN         NaN                           >      NaN
# 1               NaN         NaN                           >      NaN
# 2               NaN         NaN                           >      NaN
# 3               NaN         NaN                           >      NaN
# 4               NaN         NaN                           >      NaN
#
#   map_symbol             strat_name  subunit_comments  subunit_code  \
# ...

# %% [markdown]
# ## Lithological logs

# %%
llogs = sa_gwdata.lith_logs(wells)
llogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 8 columns):
# dh_no              168 non-null int64
# unit_hyphen        168 non-null object
# obs_no             119 non-null object
# depth_from         168 non-null float64
# depth_to           168 non-null float64
# major_lith_code    167 non-null object
# minor_lith_code    33 non-null object
# descr              168 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 10.6+ KB

# %%
llogs.head()
# Out:
#    dh_no unit_hyphen obs_no  depth_from  depth_to major_lith_code  \
# 0   7238    5928-234    NaN         0.0      1.52            SAND
# 1   7241    5928-237    NaN         0.0      1.10            CALC
# 2   7241    5928-237    NaN         1.1      2.00            CALC
# 3   7241    5928-237    NaN         2.0      2.50            CALC
# 4   7241    5928-237    NaN         2.5      4.60            CALC
#
#   minor_lith_code                                              descr
# 0             NaN                                         aeolianite
# 1             NaN  quartz arenite, grey, quartz clear and white s...
# 2             NaN  quartz arenite, off white quartz clear and whi...
# 3             NaN                            quartz arenite as above
# 4             NaN                            quartz arenite as above
